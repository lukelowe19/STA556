# %% [markdown]
# # STA 556 Week 1 Exploration
#
# This notebook is part of my Week 1 computational workflow.

# %%
import sys

print(sys.version)
x = 10
y = 25
print(x + y)
import math

math.sqrt(144)
# Out:
# 3.12.1 (main, Mar 11 2026, 12:17:56) [GCC 13.3.0]
# 35
# 12.0

# %% [markdown]
# src/hello_sta556.py creates a python file that you can work and code in, whereas notebooks/week01_exploration.ipynb allow you to create a notebook that you "chunk" up and execute specific cells. Notebooks allow you to work as you go more efficiently.

# %%
scores = [
    72,
    81,
    91,
    68,
    88,
    95,
    77,
    84
]

sum(scores) / len(scores)

import numpy as np

scores = np.array(
    scores
)

scores.mean()
scores.std()
import matplotlib.pyplot as plt

plt.hist(
    scores
)
plt.xlabel(
    "Score"
)
plt.ylabel(
    "Frequency"
)
plt.title(
    "Example Score Distribution"
)
plt.show()

plt.hist(
    scores
)
plt.savefig(
    "/workspaces/STA556/figures/scores.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# a file that is committed to Git makes sure that the computer remembers what the file is and where it is.

# %% [markdown]
# Git diff provided a history of what was modified since the previous commit.

# %% [markdown]
# If we can re-create the codespace from the GitHub repository, it means that anyone with access to the repository can re-create the codespace without any issues.

# %% [markdown]
# Saved in codespace means that in our codespace file the version we are working with will be the same. This only saves it locally to the codespace on your machine. Git commit allows us to return to a previous version of our codespace. Git push will put all of the committed work into the GitHub repository to be accessed.
